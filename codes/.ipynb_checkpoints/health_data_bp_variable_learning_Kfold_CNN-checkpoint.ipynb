# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import Adam
import keras
from tensorflow.keras.layers import *

# %% [markdown]
# # 데이터 로드
# - prep_total_2 파일은 M0번 사람 뺀 데이터, 총 105명분

# %%
data = pd.read_csv('../datasets/prep_total_2.csv', index_col= 0, encoding= 'cp949')
data = data[['검진 시 연령','체중', '허리둘레', 'BMI','수축기혈압', '이완기혈압']]
data.reset_index(inplace= True)
data.rename(columns={'고유값':'일련번호'}, inplace=True)
data.dropna(axis=0, inplace= True)

# %% [markdown]
# # 그룹화
# - 일련번호 기준으로 그룹화

# %%
grouped = data.groupby(['일련번호'])
grouped_df = {}
for key, group in grouped:
    grouped_df[key] = group

# %% [markdown]
# # 스케일링
# - Groupby한 것을 잘라서 각각 스케일링하고 시퀀스작업도 각각해야함

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
minmaxscaler = MinMaxScaler()

X_list = []
Y_list = []
for key in grouped_df.keys():
    # 스케일링
    scaled_data = minmaxscaler.fit_transform(grouped_df[key][['검진 시 연령','체중', '허리둘레', 'BMI',
                                                              '수축기혈압', '이완기혈압']])
    
    # 시퀀스작업
    for i in range(0, len(scaled_data) - 2):
        _x = scaled_data[i : i + 2]
        _y = scaled_data[i + 2][4]
        X_list.append(_x)
        Y_list.append(_y)

# %%
sequence_X = np.array(X_list)
sequence_Y = np.array(Y_list)
print(sequence_X.shape)
print(sequence_Y.shape)
# Out:
# (847, 2, 6)
# (847,)

# %% [markdown]
# # K_Fold_cross_validataion
# - 5개의 그룹으로 나눠서 검증할 것

# %%
from sklearn.model_selection import KFold

# %%
kf = KFold(n_splits=5)
kf.get_n_splits(sequence_X)
print(kf)
# Out:
# KFold(n_splits=5, random_state=None, shuffle=False)

# %% [markdown]
# # Modeling
# - CNN 모델 사용

# %%
model = Sequential()
model.add(Conv1D(32, kernel_size=5, input_shape = (sequence_X.shape[1], sequence_X.shape[2]), padding= 'same', activation= 'relu'))      
model.add(MaxPool1D(padding='same', pool_size=2))
model.add(Dropout(0.025))
model.add(Conv1D(32, kernel_size=3, padding= 'same', activation= 'relu'))
model.add(MaxPool1D(padding='same', pool_size=1))
model.add(Dropout(0.1))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.55))
model.add(Dense(1, activation = 'sigmoid'))
early_stop = keras.callbacks.EarlyStopping(monitor = 'val_loss', patience= 20)
model.compile(loss= 'mse', optimizer= 'adam')
print(model.summary())
# Out:
# Model: "sequential_28"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_54 (Conv1D)           (None, 2, 32)             992
# _________________________________________________________________
# max_pooling1d_54 (MaxPooling (None, 1, 32)             0
# _________________________________________________________________
# dropout_81 (Dropout)         (None, 1, 32)             0
# _________________________________________________________________
# conv1d_55 (Conv1D)           (None, 1, 32)             3104
# _________________________________________________________________
# max_pooling1d_55 (MaxPooling (None, 1, 32)             0
# _________________________________________________________________
# dropout_82 (Dropout)         (None, 1, 32)             0
# _________________________________________________________________
# flatten_27 (Flatten)         (None, 32)                0
# _________________________________________________________________
# dense_54 (Dense)             (None, 128)               4224
# _________________________________________________________________
# dropout_83 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_55 (Dense)             (None, 1)                 129
# =================================================================
# Total params: 8,449
# Trainable params: 8,449
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# # Learning

# %%
for train_index, test_index in kf.split(sequence_X):
    X_train, X_test = sequence_X[train_index], sequence_X[test_index]
    Y_train, Y_test = sequence_Y[train_index], sequence_Y[test_index]

    fit_hist = model.fit(X_train, Y_train, epochs = 500, validation_data= (X_test, Y_test), shuffle= False, callbacks= [early_stop])

    plt.plot(fit_hist.history['loss'], label= 'loss')
    plt.plot(fit_hist.history['val_loss'], label= 'val_loss')
    plt.legend()
    plt.grid()
    plt.show()

    predict = model.predict(X_test)
    fig = plt.figure(figsize = (7,5))
    plt.plot(Y_test[-20:], label= 'actual')
    plt.plot(predict[-20:], label= 'predict')
    plt.legend()
    plt.show()
# Out:
# Train on 677 samples, validate on 170 samples
# Epoch 1/500
# 677/677 [==============================] - 1s 1ms/sample - loss: 0.1045 - val_loss: 0.0970
# Epoch 2/500
# 677/677 [==============================] - 0s 161us/sample - loss: 0.1032 - val_loss: 0.0973
# Epoch 3/500
# 677/677 [==============================] - 0s 163us/sample - loss: 0.1035 - val_loss: 0.0971
# Epoch 4/500
# 677/677 [==============================] - 0s 150us/sample - loss: 0.1034 - val_loss: 0.0971
# Epoch 5/500
# 677/677 [==============================] - 0s 147us/sample - loss: 0.1032 - val_loss: 0.0969
# Epoch 6/500
# 677/677 [==============================] - 0s 200us/sample - loss: 0.1034 - val_loss: 0.0966
# Epoch 7/500
# 677/677 [==============================] - 0s 255us/sample - loss: 0.1028 - val_loss: 0.0969
# Epoch 8/500
# 677/677 [==============================] - 0s 228us/sample - loss: 0.1026 - val_loss: 0.0966
# Epoch 9/500
# 677/677 [==============================] - 0s 212us/sample - loss: 0.1023 - val_loss: 0.0971
# Epoch 10/500
# 677/677 [==============================] - 0s 214us/sample - loss: 0.1021 - val_loss: 0.0968
# Epoch 11/500
# 677/677 [==============================] - 0s 218us/sample - loss: 0.1028 - val_loss: 0.0962
# Epoch 12/500
# 677/677 [==============================] - 0s 211us/sample - loss: 0.1010 - val_loss: 0.0962
# Epoch 13/500
# 677/677 [==============================] - 0s 181us/sample - loss: 0.1013 - val_loss: 0.0961
# Epoch 14/500
# 677/677 [==============================] - 0s 138us/sample - loss: 0.1011 - val_loss: 0.0964
# Epoch 15/500
# 677/677 [==============================] - 0s 133us/sample - loss: 0.1012 - val_loss: 0.0969
# Epoch 16/500
# 677/677 [==============================] - 0s 133us/sample - loss: 0.1005 - val_loss: 0.0968
# Epoch 17/500
# 677/677 [==============================] - 0s 133us/sample - loss: 0.1011 - val_loss: 0.0957
# Epoch 18/500
# 677/677 [==============================] - 0s 131us/sample - loss: 0.0994 - val_loss: 0.0965
# Epoch 19/500
# 677/677 [==============================] - 0s 130us/sample - loss: 0.0988 - val_loss: 0.0976
# Epoch 20/500
# 677/677 [==============================] - 0s 134us/sample - loss: 0.1004 - val_loss: 0.0964
# Epoch 21/500
# 677/677 [==============================] - 0s 131us/sample - loss: 0.0995 - val_loss: 0.0967
# Epoch 22/500
# 677/677 [==============================] - 0s 134us/sample - loss: 0.0982 - val_loss: 0.0985
# Epoch 23/500
# 677/677 [==============================] - 0s 137us/sample - loss: 0.0995 - val_loss: 0.0975
# Epoch 6/500
# 678/678 [==============================] - 0s 243us/sample - loss: 0.0694 - val_loss: 0.0656
# Epoch 7/500
# 678/678 [==============================] - 0s 200us/sample - loss: 0.0676 - val_loss: 0.0684
# Epoch 8/500
# 678/678 [==============================] - 0s 228us/sample - loss: 0.0654 - val_loss: 0.0722
# Epoch 9/500
# 678/678 [==============================] - 0s 246us/sample - loss: 0.0646 - val_loss: 0.0706
# Epoch 10/500
# 678/678 [==============================] - 0s 218us/sample - loss: 0.0674 - val_loss: 0.0726
# Epoch 11/500
# 678/678 [==============================] - 0s 178us/sample - loss: 0.0658 - val_loss: 0.0744
# Epoch 12/500
# 678/678 [==============================] - 0s 149us/sample - loss: 0.0650 - val_loss: 0.0724
# Epoch 13/500
# 678/678 [==============================] - 0s 138us/sample - loss: 0.0658 - val_loss: 0.0710
# Epoch 14/500
# 678/678 [==============================] - 0s 140us/sample - loss: 0.0607 - val_loss: 0.0709
# Epoch 15/500
# 678/678 [==============================] - 0s 135us/sample - loss: 0.0632 - val_loss: 0.0747
# Epoch 16/500
# 678/678 [==============================] - 0s 138us/sample - loss: 0.0607 - val_loss: 0.0768
# Epoch 17/500
# 678/678 [==============================] - 0s 143us/sample - loss: 0.0607 - val_loss: 0.0780
# Epoch 18/500
# 678/678 [==============================] - 0s 143us/sample - loss: 0.0634 - val_loss: 0.0793
# Epoch 19/500
# 678/678 [==============================] - 0s 143us/sample - loss: 0.0583 - val_loss: 0.0783
# Epoch 20/500
# 678/678 [==============================] - 0s 135us/sample - loss: 0.0598 - val_loss: 0.0764
# Epoch 21/500
# 678/678 [==============================] - 0s 137us/sample - loss: 0.0600 - val_loss: 0.0860

# %%
# fig.savefig('../datasets/bp_graph/age_weight_waist_bmi_bp/2개씩.png')

# %% [markdown]
# # Test
# - test 데이터는 M0번 사람의 데이터

# %%
'''
UI에서는 내 2년치 건강검진 데이터 입력하면
model 거쳐서
예측
'''
# Out:
# '\nUI에서는 내 2년치 건강검진 데이터 입력하면\nmodel 거쳐서\n예측\n'

# %%
test = pd.read_excel('../datasets/prep_test.xlsx', index_col= 0)
test_data = test[['검진 시 연령','체중', '허리둘레', 'BMI','수축기혈압', '이완기혈압']]
test_data.rename(columns={'고유값':'일련번호'}, inplace=True)
test_data.dropna(axis=0, inplace= True)
# Out:
# c:\users\007\anaconda3\envs\machinelearning\lib\site-packages\pandas\core\frame.py:4298: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# c:\users\007\anaconda3\envs\machinelearning\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
scaled_test_data = minmaxscaler.fit_transform(test_data)
X_sequence = []
Y_sequence = []
for i in range(0, len(scaled_test_data) - 2):
    _x = scaled_test_data[i : i + 2]
    _y = scaled_test_data[i + 2][4]
    X_sequence.append(_x)
    Y_sequence.append(_y)

sequence_X = np.array(X_sequence)
sequence_Y = np.array(Y_sequence)

# %%
predict = model.predict(sequence_X)

# %%
plt.plot(sequence_Y, label = 'actual')
plt.plot(predict, label = 'predict')
plt.legend()
plt.grid()
plt.show()
