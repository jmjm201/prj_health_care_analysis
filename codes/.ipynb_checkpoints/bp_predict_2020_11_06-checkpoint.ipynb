# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import Adam
import keras
from tensorflow.keras.layers import *

# %% [markdown]
# # 데이터 로드

# %%
data = pd.read_csv('../datasets/prep_total.csv', index_col= 0)
data = data[['검진 시 연령','체중', '허리둘레', '수축기혈압', '이완기혈압']]
data.reset_index(inplace= True)
data.dropna(axis=0, inplace= True)

# %%
data.set_index(['고유값'], inplace= True)

# %% [markdown]
# # 스케일링

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
minmaxscaler = MinMaxScaler()

scaled_data = minmaxscaler.fit_transform(data)

# %%
data.reset_index(inplace=True)

# %%
scaled_data_df = pd.DataFrame(scaled_data, columns= ['검진 시 연령','체중', '허리둘레', '수축기혈압', '이완기혈압'])
scaled_data_df['고유값'] = data['고유값']
scaled_data_df
# Out:
#        검진 시 연령        체중      허리둘레   수축기혈압     이완기혈압  고유값
# 0     0.288889  0.303279  0.245902  0.5000  0.467742   M0
# 1     0.311111  0.357923  0.360656  0.3750  0.306452   M0
# 2     0.333333  0.357923  0.311475  0.3750  0.306452   M0
# 3     0.355556  0.535519  0.573770  0.5500  0.451613   M0
# 4     0.377778  0.603825  0.639344  0.5875  0.516129   M0
# ...        ...       ...       ...     ...       ...  ...
# 1062  0.533333  0.166667  0.295082  0.2375  0.258065  F30
# 1063  0.555556  0.180328  0.213115  0.3500  0.274194  F30
# 1064  0.577778  0.169399  0.196721  0.3625  0.274194  F30
# 1065  0.600000  0.176230  0.308197  0.2750  0.370968  F30
# 1066  0.622222  0.162568  0.303279  0.4875  0.435484  F30
#
# [1067 rows x 6 columns]

# %% [markdown]
# # 그룹화

# %%
grouped = scaled_data_df.groupby(['고유값'])
grouped_df = {}
for key, group in grouped:
    grouped_df[key] = group

# %% [markdown]
# # 시계열 제작

# %%
X_list = []
Y_list = []
for key in grouped_df.keys():
    a = np.array(grouped_df[key][['검진 시 연령','체중', '허리둘레', '수축기혈압', '이완기혈압']])
    for i in range(0, len(a) - 2):
        _x = a[i : i + 2]
        _y = a[i + 2][4]
        X_list.append(_x)
        Y_list.append(_y)

# %%
sequence_X = np.array(X_list)
sequence_Y = np.array(Y_list)
print(sequence_X.shape)
print(sequence_Y.shape)
# Out:
# (855, 2, 5)
# (855,)

# %% [markdown]
# # K_fold_cross_validation

# %%
from sklearn.model_selection import KFold

# %%
kf = KFold(n_splits=5)
kf.get_n_splits(sequence_X)
print(kf)
# Out:
# KFold(n_splits=5, random_state=None, shuffle=False)

# %% [markdown]
# # Modeling

# %%
model = Sequential()
model.add(Conv1D(32, kernel_size=5, input_shape = (sequence_X.shape[1], sequence_X.shape[2]), padding= 'same', activation= 'relu'))      
model.add(MaxPool1D(padding='same', pool_size=2))
model.add(Dropout(0.025))
model.add(Conv1D(32, kernel_size=3, padding= 'same', activation= 'relu'))
model.add(MaxPool1D(padding='same', pool_size=1))
model.add(Dropout(0.1))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.55))
model.add(Dense(1, activation = 'sigmoid'))
early_stop = keras.callbacks.EarlyStopping(monitor = 'val_loss', patience= 20)
model.compile(loss= 'mse', optimizer= 'adam')
print(model.summary())
# Out:
# WARNING:tensorflow:Large dropout rate: 0.55 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_2 (Conv1D)            (None, 2, 32)             832
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 1, 32)             0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 32)             0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 1, 32)             3104
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 1, 32)             0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1, 32)             0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               4224
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 8,289
# Trainable params: 8,289
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# # Learning

# %%
for train_index, test_index in kf.split(sequence_X):
    X_train, X_test = sequence_X[train_index], sequence_X[test_index]
    Y_train, Y_test = sequence_Y[train_index], sequence_Y[test_index]

    fit_hist = model.fit(X_train, Y_train, epochs = 500, validation_data= (X_test, Y_test), shuffle= False, callbacks= [early_stop])

    plt.plot(fit_hist.history['loss'], label= 'loss')
    plt.plot(fit_hist.history['val_loss'], label= 'val_loss')
    plt.legend()
    plt.grid()
    plt.show()

    predict = model.predict(X_test)
    fig = plt.figure(figsize = (7,5))
    plt.plot(Y_test[-20:], label= 'actual')
    plt.plot(predict[-20:], label= 'predict')
    plt.legend()
    plt.show()
# Out:
# Train on 684 samples, validate on 171 samples
# Epoch 1/500
# WARNING:tensorflow:Large dropout rate: 0.55 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# 684/684 [==============================] - 1s 2ms/sample - loss: 0.0249 - val_loss: 0.0376
# Epoch 2/500
# 684/684 [==============================] - 0s 166us/sample - loss: 0.0220 - val_loss: 0.0341
# Epoch 3/500
# 684/684 [==============================] - 0s 147us/sample - loss: 0.0217 - val_loss: 0.0337
# Epoch 4/500
# 684/684 [==============================] - 0s 143us/sample - loss: 0.0208 - val_loss: 0.0313
# Epoch 5/500
# 684/684 [==============================] - 0s 147us/sample - loss: 0.0197 - val_loss: 0.0291
# Epoch 6/500
# 684/684 [==============================] - 0s 152us/sample - loss: 0.0185 - val_loss: 0.0270
# Epoch 7/500
# 684/684 [==============================] - 0s 146us/sample - loss: 0.0177 - val_loss: 0.0252
# Epoch 8/500
# 684/684 [==============================] - 0s 150us/sample - loss: 0.0170 - val_loss: 0.0227
# Epoch 9/500
# 684/684 [==============================] - 0s 195us/sample - loss: 0.0168 - val_loss: 0.0221
# Epoch 10/500
# 684/684 [==============================] - 0s 223us/sample - loss: 0.0165 - val_loss: 0.0213
# Epoch 11/500
# 684/684 [==============================] - 0s 137us/sample - loss: 0.0161 - val_loss: 0.0209
# Epoch 12/500
# 684/684 [==============================] - 0s 136us/sample - loss: 0.0164 - val_loss: 0.0199
# Epoch 13/500
# 684/684 [==============================] - 0s 134us/sample - loss: 0.0163 - val_loss: 0.0197
# Epoch 14/500
# 684/684 [==============================] - 0s 139us/sample - loss: 0.0159 - val_loss: 0.0189
# Epoch 15/500
# 684/684 [==============================] - 0s 137us/sample - loss: 0.0162 - val_loss: 0.0189
# Epoch 16/500
# 684/684 [==============================] - 0s 137us/sample - loss: 0.0156 - val_loss: 0.0185
# Epoch 17/500
# 684/684 [==============================] - 0s 136us/sample - loss: 0.0160 - val_loss: 0.0187
# Epoch 18/500
# 684/684 [==============================] - 0s 134us/sample - loss: 0.0162 - val_loss: 0.0189
# Epoch 19/500
# 684/684 [==============================] - 0s 136us/sample - loss: 0.0163 - val_loss: 0.0184
# Epoch 20/500
# 684/684 [==============================] - 0s 211us/sample - loss: 0.0161 - val_loss: 0.0184
# Epoch 21/500
# 684/684 [==============================] - 0s 299us/sample - loss: 0.0156 - val_loss: 0.0180
# Epoch 22/500
# 684/684 [==============================] - 0s 251us/sample - loss: 0.0157 - val_loss: 0.0177
# Epoch 23/500
# 684/684 [==============================] - 0s 245us/sample - loss: 0.0156 - val_loss: 0.0179
# Epoch 24/500
# 684/684 [==============================] - 0s 242us/sample - loss: 0.0153 - val_loss: 0.0176
